# %%
import pandas as pd
import numpy as np

#for Label Encoding
from sklearn.preprocessing import LabelEncoder

#for Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#for Data splitting
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Loading

# %%
daf = pd.read_csv(r'C:\Users\Acer\Desktop\Machine Learning Models\Dataset\URL_ExtractedFeatures.csv')
daf.shape
# Out:
# (11430, 51)

# %% [markdown]
# # Dataframe Splitting

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, recall_score
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
def generate_accuracy_and_heatmap(model, x, y): # This is a multi label classification problem
    confusion_m = confusion_matrix(y,model.predict(x))
    sns.heatmap(confusion_m,annot=True,fmt="d")
    ac="{:.2f}".format(accuracy_score(y,model.predict(x))*100)
    recall = "{:.2f}".format(recall_score(y,model.predict(x), average='macro')*100)
    print('Accuracy : ', ac,'%')
    print('Recall : ', recall,'%')
    print("Y axis : Actual Value.")
    print("X axis : Predicted Value.")
    return 1

# %%
# generate_accuracy_and_heatmap(classifier, X_test, Y_test)

# %%
numerical_feature_columns = list(daf._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['status_enc',
#  'url_length',
#  'url_dot',
#  'url_slash',
#  'url_hyphen',
#  'url_at',
#  'url_underline',
#  'url_plus',
#  'url_hashtag',
#  'url_digits',
#  'url_special',
#  'url_percent',
#  'url_equal',
#  'url_and',
#  'url_qm',
#  'url_asterisk',
#  'url_uppercase',
#  'uppercase_ratio',
#  'digits_ratio',
#  'ascii_space',
#  'domain_length',
#  'subdomain_len',
#  'domain_digits',
#  'domain_scheme',
#  'domain_dots',
#  'domain_vowels',
#  'pre_suf_fix',
#  'tld_enc',
#  'subdomain_enc',
#  'port_enc',
#  'dir_presence',
#  'dir_heirarchy',
#  'dir_slash',
#  'dir_hyphen',
#  'dir_digits',
#  'dir_percentage',
#  'filetype_length',
#  'query_presence',
#  'query_length',
#  'query_hyphen',
#  'query_equal',
#  'query_at',
#  'query_digits',
#  'Qdigits_ratio',
#  'filetype_enc',
#  'short_url',
#  'redirection',
#  'url_email',
#  'url_validation',
#  'ip_class',
#  'domain_age']

# %%
target = 'status_enc'

# %%
k = 51 #number of variables for heatmap
cols = daf[numerical_feature_columns].corr().nlargest(k, target)[target].index
cm = daf[cols].corr()
plt.figure(figsize=(30,30))
sns.heatmap(cm, annot=True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
X = daf.loc[:, daf.columns != target]
Y = daf.loc[:, daf.columns == target]

# %%
X.shape
# Out:
# (11430, 50)

# %%
Y.shape
# Out:
# (11430, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0 , shuffle = False)

# %%
X_train.shape
# Out:
# (9144, 50)

# %%
Y_test['status_enc'].value_counts()
# Out:
# 0    1176
# 1    1110
# Name: status_enc, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

classifier = DecisionTreeClassifier(random_state=0 , max_depth=18)

classifier.fit(X_train, Y_train)

Y_predict = classifier.predict(X_test)

# %%
# clf = classifier.fit(X_train, Y_train)
# tree.plot_tree(clf)
generate_accuracy_and_heatmap(classifier, X_test, Y_test)
# Out:
# Accuracy :  86.44 %
# Recall :  86.36 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# # FEATURE SELECTION

# %%
select_feature = SelectKBest(chi2, k=50).fit(X_train, Y_train)

# %%
selected_features_df = pd.DataFrame({'Feature':list(X_train.columns),
                                     'Scores':select_feature.scores_})
selected_features_df.sort_values(by='Scores', ascending=False)
# Out:
#             Feature         Scores
# 27    subdomain_enc  836217.203403
# 9       url_special   27824.224596
# 8        url_digits   25272.287479
# 15    url_uppercase   11007.324153
# 20    subdomain_len    8934.911318
# 16  uppercase_ratio    7338.711061
# 33       dir_digits    6428.043337
# 17     digits_ratio    4772.109964
# 21    domain_digits    4611.476816
# 42    Qdigits_ratio    3171.001582
# 37     query_length    1821.608818
# 32       dir_hyphen    1753.129869
# 11        url_equal    1607.101721
# 39      query_equal    1589.478533
# 24    domain_vowels    1063.936193
# 12          url_and    1010.846373
# 13           url_qm     740.442619
# 31        dir_slash     719.219376
# 30    dir_heirarchy     700.032994
# 36   query_presence     695.404344
# 2         url_slash     451.444488
# 3        url_hyphen     390.352315
# 25      pre_suf_fix     358.263527
# 26          tld_enc     342.551698
# 1           url_dot     305.532311
# 43     filetype_enc     230.077980
# ...

# %%
X_train_chi = select_feature.transform(X_train)
X_test_chi = select_feature.transform(X_test)

# %%
X_train.head(3)
# Out:
#    url_length  url_dot  url_slash  url_hyphen  url_at  url_underline  \
# 0           0        3          3           0       0              0
# 1           1        1          5           0       0              0
# 2           1        4          5           1       0              2
#
#    url_plus  url_hashtag  url_digits  url_special  ...  query_at  \
# 0         0            0           0           37  ...         0
# 1         0            0          17           77  ...         0
# 2         0            0          19          126  ...         0
#
#    query_digits  Qdigits_ratio  filetype_enc  short_url  redirection  \
# 0             0              0            54          0            0
# 1             0              0            76          0            0
# 2             0              4            76          0            0
#
#    url_email  url_validation  ip_class  domain_age
# 0          0               1         1           3
# ...

# %%
X_train_chi
# Out:
# array([[0, 3, 3, ..., 1, 1, 3],
#        [1, 1, 5, ..., 1, 1, 3],
#        [1, 4, 5, ..., 1, 0, 3],
#        ...,
#        [0, 2, 3, ..., 1, 1, 0],
#        [1, 3, 5, ..., 1, 3, 3],
#        [0, 2, 3, ..., 1, 1, 0]], dtype=int64)

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(30,30))
plt.title('', y=2, size=20)
sns.heatmap(X_train.merge(Y_train , on = X_train.index ).corr(), 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf_dt=DecisionTreeClassifier(max_depth=18, max_features= 'auto', min_samples_leaf= 3, min_samples_split= 5, splitter= 'best',random_state=9)# , max_depth=18)
clf_dt.fit(X_train_chi, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=18, max_features='auto', min_samples_leaf=3,
#                        min_samples_split=5, random_state=9)

# %%
generate_accuracy_and_heatmap(clf_dt, X_test_chi, Y_test)
# Out:
# Accuracy :  86.57 %
# Recall :  86.54 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn import svm
clf_svm = svm.SVC()
clf_svm.fit(X_train_chi, Y_train)
# Out:
# SVC()

# %%
generate_accuracy_and_heatmap(clf_svm, X_test_chi, Y_test)
# Out:
# Accuracy :  71.83 %
# Recall :  71.93 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Nu-Support Vector Classification.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVC
clf_nsvc = make_pipeline(StandardScaler(), NuSVC())
clf_nsvc.fit(X_train_chi, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('nusvc', NuSVC())])

# %%
generate_accuracy_and_heatmap(clf_nsvc, X_test_chi, Y_test)
# Out:
# Accuracy :  82.90 %
# Recall :  82.87 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDClassifier
clf_sgd = SGDClassifier(random_state=2)
clf_sgd.fit(X_train_chi, Y_train)
# Out:
# SGDClassifier(random_state=2)

# %%
generate_accuracy_and_heatmap(clf_sgd, X_test_chi, Y_test)
# Out:
# Accuracy :  73.36 %
# Recall :  72.75 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Gaussian Process Classification

# %%
from sklearn.gaussian_process import GaussianProcessClassifier

clf_gpc = GaussianProcessClassifier()
clf_gpc.fit(X_train_chi, Y_train)
# Out:
# GaussianProcessClassifier()

# %%
generate_accuracy_and_heatmap(clf_gpc, X_test_chi, Y_test)
# Out:
# Accuracy :  81.19 %
# Recall :  80.97 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Multi-layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier

clf_mlp = MLPClassifier(random_state=15)

clf_mlp.fit(X_train_chi, Y_train)
# Out:
# MLPClassifier(random_state=15)

# %%
generate_accuracy_and_heatmap(clf_mlp, X_test_chi, Y_test)
# Out:
# Accuracy :  84.69 %
# Recall :  84.55 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

clf_adaboost = AdaBoostClassifier(n_estimators=1000, learning_rate=1)

clf_adaboost.fit(X_train_chi, Y_train)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=1000)

# %%
generate_accuracy_and_heatmap(clf_adaboost, X_test_chi, Y_test)
# Out:
# Accuracy :  88.06 %
# Recall :  88.00 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Xgboost

# %%
import xgboost as xgb

clf_xgb = xgb.XGBClassifier(max_depth=5, learning_rate=0.300000012, base_score=0.5, reg_alpha=0.4, reg_lambda=0, n_estimators=162)
#max_depth=14, learning_rate=0.3, base_score=0.5, reg_alpha=0.4, reg_lambda=0.5,n_estimators=113,eval_metric='mlogloss')

clf_xgb.fit(X_train_chi, Y_train)
# Out:
# [19:14:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=5, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=162, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0.4, reg_lambda=0, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
generate_accuracy_and_heatmap(clf_xgb, X_test_chi, Y_test)
# Out:
# Accuracy :  92.08 %
# Recall :  92.05 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %%
# generate_accuracy_and_heatmap(clf_xgb, X_train_chi, Y_train)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

clf_knn = KNeighborsClassifier(n_neighbors=5)
 
clf_knn.fit(X_train_chi, Y_train)
# Out:
# KNeighborsClassifier()

# %%
generate_accuracy_and_heatmap(clf_knn, X_test_chi, Y_test)
# Out:
# Accuracy :  83.73 %
# Recall :  83.62 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rf = RandomForestClassifier(max_depth= 23, min_samples_split= 3, n_estimators=150, random_state=72)#,random_state=19)
#91.47
# 65 19 200
clf_rf.fit(X_train_chi, Y_train)
generate_accuracy_and_heatmap(clf_rf, X_test_chi, Y_test)
# Out:
# Accuracy :  90.81 %
# Recall :  90.83 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## LightGBM

# %%
import lightgbm as lgb
clf_lgbm = lgb.LGBMClassifier(max_depth=5, learning_rate=0.300000012, reg_alpha=0.4, reg_lambda=0.5,n_estimators=163)

# max_depth=5, learning_rate=0.300000012, reg_alpha=0.4, reg_lambda=0.5,n_estimators=195
clf_lgbm.fit(X_train_chi, Y_train)
# Out:
# LGBMClassifier(learning_rate=0.300000012, max_depth=5, n_estimators=163,
#                reg_alpha=0.4, reg_lambda=0.5)

# %%
generate_accuracy_and_heatmap(clf_lgbm, X_test_chi, Y_test)
# Out:
# Accuracy :  92.34 %
# Recall :  92.32 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
clf_mnb = MultinomialNB()
clf_mnb.fit(X_train_chi, Y_train)
# Out:
# MultinomialNB()

# %%
generate_accuracy_and_heatmap(clf_mnb, X_test_chi, Y_test)
# Out:
# Accuracy :  70.82 %
# Recall :  70.71 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# ## Result Visualisation

# %%
import matplotlib.pyplot as plt

accuracy_dict = {'DT':87.01, 'SVM':71.83,'NuSVM':82.90, 'SGD':73.36, 'GPC':81.19, 'MLP':84.69, 'AdaB':88.06,
                 'XGB': 92.08, 'KNN':83.73, 'RF':90.81, 'LGBM':92.34, 'MNB':70.82}
models = list(accuracy_dict.keys())
accuracies = list(accuracy_dict.values())
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(models, accuracies, color ='coral',width = 0.7)
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy  Comparison")
plt.show()

# %%
recall_dict = {'DT':86.99, 'SVM':71.93,'NuSVM':82.87, 'SGD':72.75, 'GPC':80.97, 'MLP':84.55, 'AdaB':88.00,
                 'XGB': 92.05, 'KNN':83.62, 'RF':90.83, 'LGBM':92.32,'MNB':70.71}
models = list(recall_dict.keys())
recalls = list(recall_dict.values())
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(models, recalls, color ='greenyellow',width = 0.7)
plt.xlabel("Models")
plt.ylabel("Recall")
plt.title("Recall  Comparison")
plt.show()

# %% [markdown]
# # ENSEMBLING - STACKING

# %%
m1= RandomForestClassifier(max_depth= 23, min_samples_split= 3, n_estimators=150, random_state=72)
m2= lgb.LGBMClassifier(max_depth=5, learning_rate=0.300000012, reg_alpha=0.4, reg_lambda=0.5, n_estimators=163)

# %%
model_rf= m1.fit(X_train_chi, Y_train)
generate_accuracy_and_heatmap(model_rf, X_test_chi, Y_test)
# Out:
# Accuracy :  90.81 %
# Recall :  90.83 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %%
model_lgbm= m2.fit(X_train_chi, Y_train)
generate_accuracy_and_heatmap(model_lgbm, X_test_chi, Y_test)
# Out:
# Accuracy :  92.34 %
# Recall :  92.32 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %%
from mlxtend.classifier import StackingClassifier

# %%
clf_stack = StackingClassifier(classifiers =[m2], meta_classifier = m1, use_probas = True, use_features_in_secondary = True)

# %%
clf_stack.fit(X_train_chi, Y_train)
# Out:
# StackingClassifier(classifiers=[LGBMClassifier(learning_rate=0.300000012,
#                                                max_depth=5, n_estimators=163,
#                                                reg_alpha=0.4, reg_lambda=0.5)],
#                    meta_classifier=RandomForestClassifier(max_depth=23,
#                                                           min_samples_split=3,
#                                                           n_estimators=150,
#                                                           random_state=72),
#                    use_features_in_secondary=True, use_probas=True)

# %%
generate_accuracy_and_heatmap(clf_stack, X_test_chi, Y_test)
# Out:
# Accuracy :  92.48 %
# Recall :  92.46 %
# Y axis : Actual Value.
# X axis : Predicted Value.
# 1

# %% [markdown]
# # Transforming into Pickle

# %%
import pickle
pickle.dump(clf_stack,open('phishingURL.pkl','wb'))
